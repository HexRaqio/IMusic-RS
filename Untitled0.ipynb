# %% [markdown]
# <a href="https://colab.research.google.com/github/RaqioDev/IMusic-RS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array ([-40,14, 32, 46, 59, 72, 100], dtype=float)

# %%
#capa = tf.keras.layers.Dense(units=1,input_shape=[1])
#modelo = tf.keras.Sequential([capa])

oculta1 = tf.keras.layers.Dense(units=3, input_shape=[1])
oculta2 = tf.keras.layers.Dense(units=3)
salida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([oculta1, oculta2, salida])

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
 )

# %%
print("Starting...")
historial = modelo.fit(celsius, fahrenheit, epochs=4000, verbose=False)
print("Finished")
# Out:
# Starting...
# Finished

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])

# %%
print("Prediccion")
resultado = modelo.predict(np.array([100.0]))
print("El resultado es " + str(resultado) + " fahrenheit")
# Out:
# Prediccion
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# El resultado es [[211.74466]] fahrenheit

# %%
print("Variables internas del modelo")
#print(capa.get_weights())
print(oculta1.get_weights())
print(oculta2.get_weights())
print(salida.get_weights())
# Out:
# Variables internas del modelo
# [array([[ 0.26365054, -0.02854351,  0.68470365]], dtype=float32), array([4.9916644, 3.4971435, 5.3211117], dtype=float32)]
# [array([[ 0.70738655, -0.20137516,  0.6982954 ],
#        [ 0.18627393, -0.00528556, -0.11006036],
#        [ 1.4023738 , -0.88584095, -0.3093777 ]], dtype=float32), array([ 5.447636 , -4.885326 , -1.3073078], dtype=float32)]
# [array([[ 1.2160872 ],
#        [-0.6206307 ],
#        [-0.02407821]], dtype=float32), array([4.577411], dtype=float32)]
